# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\kisho\OneDrive\Music\Desktop\spotify.csv")
df
# Out:
#                      track_id                                  track_name  \
# 0      2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1      4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2      59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3      5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4      1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
# ...                       ...                                         ...
# 62312  3eHDwMQYPEziy2DWRBNoLv                        Sani - G.O.A.T Remix
# 62313  5hHtCqkNv5eo99OrEFFcgS                            Life of Bachelor
# 62314  08foF9YHgKmIgOy3xMWRZy                                     Yo Baby
# 62315  2wLFbVlQGKJSd9lwzwL47F                           Fast Fast Vadiley
# 62316  5OYxwYeFfumMTAoAdVeet3             Moonu Moonu Moonu (From "3:33")
#
#                                              artist_name  year  popularity  \
# ...

# %%
df.isnull().sum()
# Out:
# track_id            0
# track_name          0
# artist_name         0
# year                0
# popularity          0
# artwork_url         0
# album_name          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# track_url           0
# language            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# track_id            0
# track_name          0
# artist_name         0
# year                0
# popularity          0
# artwork_url         0
# album_name          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# track_url           0
# language            0
# dtype: int64

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\kisho\OneDrive\Music\Desktop\spotify.csv")

df.duplicated().sum()
# Out:
# 78

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (62239, 22)

# %%
df.head()
# Out:
#                  track_id                                  track_name  \
# 0  2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1  4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2  59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3  5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4  1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                          artwork_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273ce9c65...
# ...

# %%
df["key"]
# Out:
# 0         8
# 1        10
# 2         2
# 3         7
# 4         7
#          ..
# 62312     7
# 62313     8
# 62314     7
# 62315     1
# 62316     6
# Name: key, Length: 62239, dtype: int64

# %%
l = []
for i in df["key"]:
    l.append(str(i)[:3])
l
# Out:
# ['8',
#  '10',
#  '2',
#  '7',
#  '7',
#  '7',
#  '9',
#  '4',
#  '4',
#  '1',
#  '4',
#  '7',
#  '7',
#  '7',
#  '11',
#  '4',
#  '3',
#  '7',
#  '6',
#  '0',
#  '0',
#  '9',
#  '11',
#  '2',
#  '2',
#  '11',
#  '1',
#  '10',
#  '10',
#  '0',
#  '10',
#  '10',
#  '1',
#  '1',
#  '0',
#  '0',
#  '11',
#  '10',
#  '0',
#  '0',
#  '4',
#  '2',
#  '0',
#  '1',
#  '6',
#  '10',
#  '1',
#  '11',
#  '10',
#  '6',
#  '1',
#  '1',
#  '2',
#  '11',
#  '5',
#  '6',
#  '1',
#  '10',
#  '1',
#  '7',
#  '2',
#  '10',
#  '7',
#  '10',
#  '7',
#  '5',
#  '5',
#  '5',
#  '5',
#  '8',
#  '1',
#  '3',
#  '7',
#  '4',
#  '2',
#  '11',
#  '0',
#  '11',
#  '10',
#  '11',
#  '10',
#  '0',
#  '6',
#  '1',
#  '6',
#  '1',
#  '1',
#  '0',
#  '10',
#  '1',
#  '9',
#  '6',
#  '5',
#  '7',
#  '10',
#  '10',
#  '1',
#  '5',
#  '9',
#  '2',
#  '6',
#  '11',
#  '0',
#  '7',
#  '2',
#  '10',
#  '1',
#  '8',
#  '4',
#  '10',
#  '7',
#  '6',
#  '7',
#  '0',
#  '10',
#  '7',
#  '10',
#  '7',
#  '1',
#  '1',
#  '1',
# ...

# %%
df["album_name"]=df["album_name"].str.replace(" ",",")
df["artist_name"]=df["artist_name"].str.replace(' ','')
df
# Out:
#                      track_id                                  track_name  \
# 0      2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1      4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2      59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3      5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4      1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
# ...                       ...                                         ...
# 62312  3eHDwMQYPEziy2DWRBNoLv                        Sani - G.O.A.T Remix
# 62313  5hHtCqkNv5eo99OrEFFcgS                            Life of Bachelor
# 62314  08foF9YHgKmIgOy3xMWRZy                                     Yo Baby
# 62315  2wLFbVlQGKJSd9lwzwL47F                           Fast Fast Vadiley
# 62316  5OYxwYeFfumMTAoAdVeet3             Moonu Moonu Moonu (From "3:33")
#
#                                              artist_name  year  popularity  \
# ...

# %%
df["artist_name"]=df["artist_name"].str.replace(' ','')
df
# Out:
#                      track_id                                  track_name  \
# 0      2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1      4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2      59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3      5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4      1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
# ...                       ...                                         ...
# 62312  3eHDwMQYPEziy2DWRBNoLv                        Sani - G.O.A.T Remix
# 62313  5hHtCqkNv5eo99OrEFFcgS                            Life of Bachelor
# 62314  08foF9YHgKmIgOy3xMWRZy                                     Yo Baby
# 62315  2wLFbVlQGKJSd9lwzwL47F                           Fast Fast Vadiley
# 62316  5OYxwYeFfumMTAoAdVeet3             Moonu Moonu Moonu (From "3:33")
#
#                                              artist_name  year  popularity  \
# ...

# %%
df["track_url"] = df["artist_name"].astype(str) + '_' + df["album_name"].astype(str) + '_' + df["key"].astype(str)
df
# Out:
#                      track_id                                  track_name  \
# 0      2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1      4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2      59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3      5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4      1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
# ...                       ...                                         ...
# 62312  3eHDwMQYPEziy2DWRBNoLv                        Sani - G.O.A.T Remix
# 62313  5hHtCqkNv5eo99OrEFFcgS                            Life of Bachelor
# 62314  08foF9YHgKmIgOy3xMWRZy                                     Yo Baby
# 62315  2wLFbVlQGKJSd9lwzwL47F                           Fast Fast Vadiley
# 62316  5OYxwYeFfumMTAoAdVeet3             Moonu Moonu Moonu (From "3:33")
#
#                                              artist_name  year  popularity  \
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=20000)

# %%
vectors = cv.fit_transform(df["track_url"])

# %%
vectors.shape
# Out:
# (62239, 20000)

# %%
features=cv.get_feature_names_out()
print(features[:10])
# Out:
# ['00' '001' '00pm_8' '00s' '00s_2' '00s_5' '01' '01_0' '01_1' '01_10']

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Sample text corpus
corpus = [
    "dog and cat",
    "dog and mouse",
    "cat and mouse",
    "car and engine"
]

# Vectorize the corpus
cv = CountVectorizer()
vectors = cv.fit_transform(corpus).toarray()

# Compute cosine similarity
similarity = cosine_similarity(vectors)

# Output similarity matrix
print(similarity)
# Out:
# [[1.         0.66666667 0.66666667 0.33333333]
#  [0.66666667 1.         0.66666667 0.33333333]
#  [0.66666667 0.66666667 1.         0.33333333]
#  [0.33333333 0.33333333 0.33333333 1.        ]]

# %%
sorted(list(enumerate(similarity[0])))
# Out:
# [(0, 1.0000000000000002),
#  (1, 0.6666666666666669),
#  (2, 0.6666666666666669),
#  (3, 0.3333333333333334)]

# %%
print("Feature shape:", features.shape)
print("Feature sample:", features[:5])
# Out:
# Feature shape: (20000,)
# Feature sample: ['00' '001' '00pm_8' '00s' '00s_2']
